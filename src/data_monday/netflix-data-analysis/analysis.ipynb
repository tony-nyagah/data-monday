# %% [markdown]
# <center><img src="redpopcorn.jpg"></center>

# %% [markdown]
# **Netflix**! What started in 1997 as a DVD rental service has since exploded into one of the largest entertainment and media companies.
#
# Given the large number of movies and series available on the platform, it is a perfect opportunity to flex your exploratory data analysis skills and dive into the entertainment industry.
#
# You work for a production company that specializes in nostalgic styles. You want to do some research on movies released in the 1990's. You'll delve into Netflix data and perform exploratory data analysis to better understand this awesome movie decade!
#
# You have been supplied with the dataset `netflix_data.csv`, along with the following table detailing the column names and descriptions. Feel free to experiment further after submitting!
#
# ## The data
# ### **netflix_data.csv**
# | Column | Description |
# |--------|-------------|
# | `show_id` | The ID of the show |
# | `type` | Type of show |
# | `title` | Title of the show |
# | `director` | Director of the show |
# | `cast` | Cast of the show |
# | `country` | Country of origin |
# | `date_added` | Date added to Netflix |
# | `release_year` | Year of Netflix release |
# | `duration` | Duration of the show in minutes |
# | `description` | Description of the show |
# | `genre` | Show genre |

# %%
# Importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Read in the Netflix CSV as a DataFrame
netflix_df = pd.read_csv("netflix_data.csv")

# %% [markdown]
# 1. Filter the data for movies releases in the 1990s.

# %%
before_2000 = netflix_df["release_year"] < 2000
after_1990 = netflix_df["release_year"] >= 1990
movie_type = netflix_df["type"] == "Movie"
netflix_1990s = netflix_df[after_1990 & before_2000 & movie_type]
netflix_1990s.head()
# Out:
#     show_id   type                            title            director  \
# 7        s8  Movie                              187      Kevin Reynolds
# 166    s167  Movie                A Dangerous Woman  Stephen Gyllenhaal
# 210    s211  Movie           A Night at the Roxbury    John Fortenberry
# 238    s239  Movie  A Thin Line Between Love & Hate     Martin Lawrence
# 273    s274  Movie                     Aashik Awara         Umesh Mehra
#
#                                                   cast        country  \
# 7    Samuel L. Jackson, John Heard, Kelly Rowan, Cl...  United States
# 166  Debra Winger, Barbara Hershey, Gabriel Byrne, ...  United States
# 210  Will Ferrell, Chris Kattan, Dan Hedaya, Molly ...  United States
# 238  Martin Lawrence, Lynn Whitfield, Regina King, ...  United States
# 273  Saif Ali Khan, Mamta Kulkarni, Mohnish Bahl, S...          India
#
#            date_added  release_year  duration  \
# 7    November 1, 2019          1997       119
# ...

# %%
print(f"Minimun year: {netflix_1990s.release_year.min()}")
print(f"Maximum year: {netflix_1990s.release_year.max()}")
# Out:
# Minimun year: 1990
# Maximum year: 1999

# %% [markdown]
# 2. Find the most frequent movie duration.

# %%
plt.figure(figsize=(10,6))
plt.hist(netflix_1990s["duration"], bins=20, edgecolor="black")
plt.title("Distribution of Movie Duration in the 1990s")
plt.xlabel("Duration (in minutes)")
plt.ylabel("Number of Movies")
# Out:
# Text(0, 0.5, 'Number of Movies')

# %%
most_frequent_duration = netflix_1990s.duration.mode()[0]
print(f"Most frequent movie duration in the 1990s was {most_frequent_duration} minutes.")
# Out:
# Most frequent movie duration in the 1990s was 94 minutes.

# %% [markdown]
# 3. Count the number of short action movies from the 1990s

# %%
action_movies = (netflix_1990s.genre == "Action")
less_than_90_minutes = (netflix_1990s.duration <= 90)
short_action_movies = netflix_1990s[action_movies & less_than_90_minutes]
short_action_movies
# Out:
#      show_id   type                               title  \
# 2038   s2039  Movie           EVANGELION: DEATH (TRUE)²
# 2707   s2708  Movie                                Hero
# 3717   s3718  Movie                   Look Out, Officer
# 4422   s4423  Movie  National Lampoon's Loaded Weapon 1
# 4786   s4787  Movie                        Passenger 57
# 5298   s5299  Movie                 Rumble in the Bronx
# 6113   s6114  Movie                 The Bare-Footed Kid
# 6329   s6330  Movie               The End of Evangelion
#
#                             director  \
# 2038                    Hideaki Anno
# 2707                      Corey Yuen
# 3717                      Sze Yu Lau
# 4422                   Gene Quintano
# 4786                     Kevin Hooks
# 5298                    Stanley Tong
# 6113                      Johnnie To
# 6329  Hideaki Anno, Kazuya Tsurumaki
#
#                                                    cast        country  \
# ...

# %%
print(f"Number of short action movies in the 1990s was {len(short_action_movies)}.")
# Out:
# Number of short action movies in the 1990s was 8.
